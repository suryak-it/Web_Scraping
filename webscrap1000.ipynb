# %% [markdown]
# <a href="https://colab.research.google.com/github/suryak-it/Web_Scraping/blob/main/webscrap1000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Web scraping for the first website
url1 = 'https://builtin.com/companies/tech/aws-companies?page={}'
base_url1 = 'https://builtin.com/companies/tech/aws-companies?page={}'
company_data1 = []

for page_number in range(1, 44):
    current_url = base_url1.format(page_number)
    r1 = requests.get(current_url)
    soup1 = BeautifulSoup(r1.text, 'html.parser')
    company_list1 = soup1.find_all("h2", class_="fw-extrabold fs-xl hover-underline d-inline-block company-title-clamp mb-0")
    company_data1.extend([company.get_text(strip=True) for company in company_list1])

# Web scraping for the second website
url2 = 'https://www.forbes.com/lists/cloud100/?sh=1a9a50077d9c'
r2 = requests.get(url2)
soup2 = BeautifulSoup(r2.text, 'html.parser')
company_list2 = soup2.find_all("div", class_="organizationName second table-cell company")
company_data2 = [company.get_text(strip=True) for company in company_list2]

# Web scraping for the third website
url3 = 'https://www.builtinla.com/companies/tech/aws-companies'
r3 = requests.get(url3)
soup3 = BeautifulSoup(r3.text, 'html.parser')
company_list3 = soup2.find_all("h2", class_="fw-extrabold fs-xl hover-underline d-inline-block company-title-clamp mb-0")
company_data3 = [company.get_text(strip=True) for company in company_list3]

# Combine the company data from both sources
all_company_data = company_data1 + company_data2

# Create a CSV file and write the data
csv_file_path = 'combined_companies.csv'
with open(csv_file_path, 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write the header row
    csv_writer.writerow(['Company Name'])

    # Write the combined company data to the CSV file
    for company in all_company_data:
        csv_writer.writerow([company])

print(f"Data has been successfully written to {csv_file_path}.")
# Out:
# Data has been successfully written to combined_companies.csv.

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Function to scrape company names from a given URL
def scrape_company_names(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    company_list = soup.find_all("h2", class_="fw-extrabold fs-xl hover-underline d-inline-block company-title-clamp mb-0")
    return [company.get_text(strip=True) for company in company_list]

# Base URL
base_url = 'https://www.builtinla.com/companies?page={}'

# Number of pages to scrape (382 in this case)
total_pages = 382

# List to store company names
company_names = []

# Iterate over each page and scrape company names
for page_number in range(1, total_pages + 1):
    current_url = base_url.format(page_number)
    company_names.extend(scrape_company_names(current_url))

# Save company names to CSV file
csv_file_path = 'company_names.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write the header row
    csv_writer.writerow(['Company Name'])

    # Write the company names to the CSV file
    for company_name in company_names:
        csv_writer.writerow([company_name])

print(f"Company names have been successfully written to {csv_file_path}.")
# Out:
# Company names have been successfully written to company_names.csv.

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Function to scrape links and company names from a given URL
def scrape_data(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    # Scrape links
    link_list = soup.find_all("a", class_="info-item company-website-link")  # Adjust the class based on your HTML structure
    links = [link['href'] for link in link_list]

    # Scrape company names
    company_list = soup.find_all("h2", class_="fw-extrabold fs-xl hover-underline d-inline-block company-title-clamp mb-0")
    company_names = [company.get_text(strip=True) for company in company_list]

    return list(zip(company_names, links))

# Base URL
base_url = 'https://www.builtinla.com/companies?page={}'

# Number of pages to scrape (382 in this case)
total_pages = 382

# List to store companies and their links
companies_data = []

# Iterate over each page and scrape data
for page_number in range(1, total_pages + 1):
    current_url = base_url.format(page_number)
    companies_data.extend(scrape_data(current_url))

# Print companies and their links
for company, link in companies_data:
    print(f"Company: {company}\nLink: {link}\n")

# Save companies and their links to CSV file
csv_file_path = 'companies_data.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write the header row
    csv_writer.writerow(['Company Name', 'Link'])

    # Write the companies and links to the CSV file
    csv_writer.writerows(companies_data)

print(f"Companies and their links have been successfully written to {csv_file_path}.")

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Function to scrape company names from a given URL
def scrape_company_names(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    # Adjust the class based on your HTML structure
    company_list = soup.find_all("h2", class_="fw-extrabold fs-xl hover-underline d-inline-block company-title-clamp mb-0")

    return [company.get_text(strip=True) for company in company_list]

def scrape_company_links(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    # Adjust the class based on your HTML structure
    company_link = soup.find_all("a", class_="btn btn-lg btn-outline-primary w-100")

    return [company.get_text(strip=True) for company in company_link]

# Replace this URL with the actual URL of the page you want to scrape
url = 'https://www.builtinla.com/companies?page=1'


# Scrape company names and links
company_names = scrape_company_names(url)
company_links = scrape_company_links(url)

# Save company data to CSV file
csv_file_path = 'company_data.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write the header row
    csv_writer.writerow(['Company Name', 'Company Link'])

    # Write the company data to the CSV file
    for company_name, company_link in zip(company_names, company_links):
        csv_writer.writerow([company_name, company_link])

print(f"Company names and links have been successfully written to {csv_file_path}.")

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Function to scrape company names and links from a given URL
def scrape_company_links(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    # Adjust the class based on your HTML structure
    company_links = soup.find_all("a", class_="btn btn-lg btn-outline-primary w-100")

    return [company.get("href") for company in company_links]

# Replace this URL with the actual URL of the page you want to scrape
url = 'https://www.builtinla.com/companies?page=1'

# Scrape company links
company_links = scrape_company_links(url)

# Save company links to CSV file
csv_file_path = 'company_links.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write the header row
    csv_writer.writerow(['Company Link'])

    # Write the company links to the CSV file
    for link in company_links:
        csv_writer.writerow([link])

print(f"Company links have been successfully written to {csv_file_path}.")

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Function to scrape company names and links from a given URL
def scrape_company_data(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    # Scraping company names
    company_names = []
    company_list = soup.find_all("h2", class_="fw-extrabold fs-xl hover-underline d-inline-block company-title-clamp mb-0")
    company_names = [company.get_text(strip=True) for company in company_list]

    # Scraping company links
    company_links = []
    company_elements = soup.find_all("a", class_="btn btn-lg btn-outline-primary w-100")
    company_links = [company.get("href") for company in company_elements]

    return list(zip(company_names, company_links))

# Base URL
base_url = 'https://www.builtinla.com/companies?page={}'

# Number of pages to scrape (382 in this case)
total_pages = 382

# List to store company data (names and links)
all_companies_data = []

# Iterate over each page and scrape company data
for page_number in range(1, total_pages + 1):
    current_url = base_url.format(page_number)
    companies_data = scrape_company_data(current_url)
    all_companies_data.extend(companies_data)

# Save all company data to CSV file
csv_file_path = 'all_companies_data.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write the header row
    csv_writer.writerow(['Company Name', 'Company Link'])

    # Write the company data to the CSV file
    for company in all_companies_data:
        csv_writer.writerow(company)

print(f"All company data (names and links) have been successfully written to {csv_file_path}.")

# %%
# !pip install selenium
chrome_driver_path = '/content/drive/MyDrive/chromedriver'

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Function to scrape official link from the company detail page
def scrape_official_link(company_detail_url):
    # Add your logic to extract the official link based on the structure of the company detail page
    # This is a placeholder, modify it according to the actual structure
    official_link = "Not available"

    # Example:
    # r = requests.get(company_detail_url)
    # soup = BeautifulSoup(r.text, 'html.parser')
    # official_link = soup.find("a", class_="official-link-class").get("href")

    return official_link

# Function to scrape company names and links from a given URL
def scrape_company_data(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    # Scraping company names
    company_names = []
    company_list = soup.find_all("h2", class_="fw-extrabold fs-xl hover-underline d-inline-block company-title-clamp mb-0")
    company_names = [company.get_text(strip=True) for company in company_list]

    # Scraping company links
    company_links = []
    company_elements = soup.find_all("a", class_="btn btn-lg btn-outline-primary w-100")
    company_links = [company.get("href") for company in company_elements]

    # Combine names and links
    companies_data = list(zip(company_names, company_links))

    # Scraping official links from each company's detail page
    for i, (company_name, company_detail_url) in enumerate(companies_data):
        print(f"Scraping {i + 1}/{len(companies_data)}: {company_name}")
        official_link = scrape_official_link(company_detail_url)
        companies_data[i] += (official_link,)

    return companies_data

# Base URL
base_url = 'https://www.builtinla.com/companies?page={}'

# Number of pages to scrape (382 in this case)
total_pages = 382

# List to store company data (names, links, and official links)
all_companies_data = []

# Iterate over each page and scrape company data
for page_number in range(1, total_pages + 1):
    current_url = base_url.format(page_number)
    companies_data = scrape_company_data(current_url)
    all_companies_data.extend(companies_data)

# Save all company data to CSV file
csv_file_path = 'all_companies_data.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write the header row
    csv_writer.writerow(['Company Name', 'Company Link', 'Official Link'])

    # Write the company data to the CSV file
    for company in all_companies_data:
        csv_writer.writerow(company)

print(f"All company data (names, links, and official links) have been successfully written to {csv_file_path}.")

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Function to scrape company names, links, and official links from a given URL
def scrape_company_data(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    # Scraping company names and links
    company_names = []
    company_links = []
    company_list = soup.find_all("h2", class_="fw-extrabold fs-xl hover-underline d-inline-block company-title-clamp mb-0")
    for company in company_list:
        company_name = company.get_text(strip=True)
        company_link_element = company.find("a")
        company_link = company_link_element["href"] if company_link_element else None
        company_names.append(company_name)
        company_links.append(company_link)

    # Scraping official links from company detail pages
    official_links = []
    for company_link in company_links:
        if company_link:
            company_detail_page = requests.get(company_link)
            company_detail_soup = BeautifulSoup(company_detail_page.text, 'html.parser')
            official_link_element = company_detail_soup.find("a", text="Official Website")
            official_link = official_link_element["href"] if official_link_element else "Not available"
            official_links.append(official_link)
        else:
            official_links.append("Not available")

    # Combine names, links, and official links
    companies_data = list(zip(company_names, company_links, official_links))

    return companies_data

# Base URL
base_url = 'https://www.builtinla.com/companies?page={}'

# Number of pages to scrape (382 in this case)
total_pages = 382

# List to store company data (names, links, and official links)
all_companies_data = []

# Iterate over each page and scrape company data
for page_number in range(1, total_pages + 1):
    current_url = base_url.format(page_number)
    companies_data = scrape_company_data(current_url)
    all_companies_data.extend(companies_data)

# Save all company data to CSV file
csv_file_path = 'all_companies_data.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write the header row
    csv_writer.writerow(['Company Name', 'Company Link', 'Official Link'])

    # Write the company data to the CSV file
    for company in all_companies_data:
        csv_writer.writerow(company)

print(f"All company data (names, links, and official links) have been successfully written to {csv_file_path}.")
# Out:
# All company data (names, links, and official links) have been successfully written to all_companies_data.csv.

# %%
from bs4 import BeautifulSoup


# Parse the HTML content
soup = BeautifulSoup(html, 'html.parser')

# Find the anchor tag with the specified class
company_link_element = soup.find('a', class_='info-item company-website-link')

# Extract the href attribute (company link)
company_link = company_link_element['href'] if company_link_element else None

# Print the company link
print("Company Link:", company_link)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-da7f97b361c7> in <cell line: 5>()
#       3
#       4 # Parse the HTML content
# ----> 5 soup = BeautifulSoup(html, 'html.parser')
#       6
#       7 # Find the anchor tag with the specified class
#
# NameError: name 'html' is not defined

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Function to scrape company links from a given URL
def scrape_company_links(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    # Scraping company links
    company_links = []
    company_elements = soup.find_all("a", class_="btn btn-lg btn-outline-primary w-100")
    company_links = [company.get("href") for company in company_elements]

    return company_links

# Base URL
base_url = 'https://www.builtinla.com/companies?page={}'

# Number of pages to scrape (382 in this case)
total_pages = 382

# List to store company links
all_company_links = []

# Iterate over each page and scrape company links
for page_number in range(1, total_pages + 1):
    current_url = base_url.format(page_number)
    company_links = scrape_company_links(current_url)
    all_company_links.extend(company_links)

# Print all company links
for i, link in enumerate(all_company_links, start=1):
    print(f"Company Link {i}: {link}")

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Function to scrape company links from a given URL
def scrape_company_links(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    # Scraping company links
    company_links = []
    company_elements = soup.find_all("a", class_="btn btn-lg btn-outline-primary w-100")

    for company in company_elements:
        try:
            company_link = company.get("href")
            company_links.append(company_link)
        except TypeError:
            print(f"Failed to retrieve data from {url}")
            company_links.append(None)

    return company_links

# Base URL
base_url = 'https://www.builtinla.com/companies?page={}'

# Number of pages to scrape (382 in this case)
total_pages = 382

# List to store company links
all_company_links = []

# Iterate over each page and scrape company links
for page_number in range(1, total_pages + 1):
    current_url = base_url.format(page_number)
    company_links = scrape_company_links(current_url)
    all_company_links.extend(company_links)

# Print all company links
for i, link in enumerate(all_company_links, start=1):
    print(f"Company Link {i}: {link}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Company Link 2641: https://builtinla.com/company/gravity-labs
# Company Link 2642: https://builtinla.com/company/entidad
# Company Link 2643: https://builtinla.com/company/iproyal
# Company Link 2644: https://builtinla.com/company/trigger-group
# Company Link 2645: https://builtinla.com/company/get-covered
# Company Link 2646: https://builtinla.com/company/platform-factory-inc
# Company Link 2647: https://builtinla.com/company/touch-health
# Company Link 2648: https://builtinla.com/company/cadre
# Company Link 2649: https://builtinla.com/company/aglet
# Company Link 2650: https://builtinla.com/company/workreduce
# Company Link 2651: https://builtinla.com/company/laa-vision-events
# Company Link 2652: https://builtinla.com/company/extend-view
# Company Link 2653: https://builtinla.com/company/top-rated-general-contractors
# Company Link 2654: https://builtinla.com/company/envoy-media-group-0
# Company Link 2655: https://builtinla.com/company/dealer-credit-resources-inc
# Company Link 2656: https://builtinla.com/company/clarematrix
# Company Link 2657: https://builtinla.com/company/cadence-translate
# Company Link 2658: https://builtinla.com/company/pretmetlednl
# Company Link 2659: https://builtinla.com/company/nosto
# Company Link 2660: https://builtinla.com/company/clever-programmer
# Company Link 2661: https://builtinla.com/company/amazevr
# Company Link 2662: https://builtinla.com/company/hia-technologies-inc
# Company Link 2663: https://builtinla.com/company/pearpop
# Company Link 2664: https://builtinla.com/company/revealbot
# Company Link 2665: https://builtinla.com/company/schmidt-futures
# Company Link 2666: https://builtinla.com/company/mascot
# Company Link 2667: https://builtinla.com/company/reputation-america
# Company Link 2668: https://builtinla.com/company/swimply
# Company Link 2669: https://builtinla.com/company/canvas-ww
# Company Link 2670: https://builtinla.com/company/uniper-care
# Company Link 2671: https://builtinla.com/company/briq
# Company Link 2672: https://builtinla.com/company/way
# Company Link 2673: https://builtinla.com/company/kindra
# Company Link 2674: https://builtinla.com/company/commissioner
# Company Link 2675: https://builtinla.com/company/endgame
# Company Link 2676: https://builtinla.com/company/audacy
# Company Link 2677: https://builtinla.com/company/mobile-app-agency-manchester
# Company Link 2678: https://builtinla.com/company/bixby-south-tulsa-funeral-service-crematory
# Company Link 2679: https://builtinla.com/company/plant-prefab
# Company Link 2680: https://builtinla.com/company/quantil-networks-inc-0
# Company Link 2681: https://builtinla.com/company/remento-0
# Company Link 2682: https://builtinla.com/company/movers-shakers
# Company Link 2683: https://builtinla.com/company/roundrobin
# Company Link 2684: https://builtinla.com/company/dreamhost
# Company Link 2685: https://builtinla.com/company/joseph-eye-and-laser
# Company Link 2686: https://builtinla.com/company/fullfill-inc
# Company Link 2687: https://builtinla.com/company/cycle-cpa-inc
# Company Link 2688: https://builtinla.com/company/parkside-collectibles
# Company Link 2689: https://builtinla.com/company/digitalce-inc
# Company Link 2690: https://builtinla.com/company/santini-studio
# Company Link 2691: https://builtinla.com/company/weebid
# Company Link 2692: https://builtinla.com/company/day-j
# Company Link 2693: https://builtinla.com/company/zencastr
# Company Link 2694: https://builtinla.com/company/changeup
# Company Link 2695: https://builtinla.com/company/tend-0
# Company Link 2696: https://builtinla.com/company/intro
# Company Link 2697: https://builtinla.com/company/allvoices
# Company Link 2698: https://builtinla.com/company/14th-round-inc
# Company Link 2699: https://builtinla.com/company/shape-software-inc
# Company Link 2700: https://builtinla.com/company/whym-wallet
# Company Link 2701: https://builtinla.com/company/cosm
# Company Link 2702: https://builtinla.com/company/famous-industries-inc
# Company Link 2703: https://builtinla.com/company/code-n-webs
# Company Link 2704: https://builtinla.com/company/code-n-animations
# Company Link 2705: https://builtinla.com/company/mojotech
# Company Link 2706: https://builtinla.com/company/parentsquare-inc
# Company Link 2707: https://builtinla.com/company/backlot
# Company Link 2708: https://builtinla.com/company/mntn
# Company Link 2709: https://builtinla.com/company/western-psychological-services-0
# Company Link 2710: https://builtinla.com/company/artium
# Company Link 2711: https://builtinla.com/company/quantumblack-ai-mckinsey
# Company Link 2712: https://builtinla.com/company/age
# Company Link 2713: https://builtinla.com/company/graf-lantz
# Company Link 2714: https://builtinla.com/company/veo
# Company Link 2715: https://builtinla.com/company/momentranks
# Company Link 2716: https://builtinla.com/company/uptech-studio
# Company Link 2717: https://builtinla.com/company/spp-inc
# Company Link 2718: https://builtinla.com/company/huxly-1
# Company Link 2719: https://builtinla.com/company/proto
# Company Link 2720: https://builtinla.com/company/rockstar-pro-movers
# Company Link 2721: https://builtinla.com/company/valence-0
# Company Link 2722: https://builtinla.com/company/datum
# Company Link 2723: https://builtinla.com/company/tiny-elephant
# Company Link 2724: https://builtinla.com/node/122380
# Company Link 2725: https://builtinla.com/company/goodones
# Company Link 2726: https://builtinla.com/company/tae-technologies
# Company Link 2727: https://builtinla.com/company/creatordao
# Company Link 2728: https://builtinla.com/company/mudwtr
# Company Link 2729: https://builtinla.com/company/ryz-labs
# Company Link 2730: https://builtinla.com/company/bloom-ads
# Company Link 2731: https://builtinla.com/company/cake-equity
# Company Link 2732: https://builtinla.com/company/remento
# Company Link 2733: https://builtinla.com/company/nook-0
# Company Link 2734: https://builtinla.com/company/flawless
# Company Link 2735: https://builtinla.com/company/nax-group
# Company Link 2736: https://builtinla.com/company/blazetech
# Company Link 2737: https://builtinla.com/company/california-caregivers-alliance-0
# Company Link 2738: https://builtinla.com/company/emrcpr
# Company Link 2739: https://builtinla.com/company/magic-services-llc-0
# Company Link 2740: https://builtinla.com/company/elevate-money
# Company Link 2741: https://builtinla.com/company/i-heart-travel-inc
# Company Link 2742: https://builtinla.com/company/newprint
# Company Link 2743: https://builtinla.com/company/weedbates
# Company Link 2744: https://builtinla.com/company/expert-towing-2
# Company Link 2745: https://builtinla.com/node/131739
# Company Link 2746: https://builtinla.com/company/live-data-technologies
# Company Link 2747: https://builtinla.com/company/people-science
# Company Link 2748: https://builtinla.com/company/pazi-performance
# Company Link 2749: https://builtinla.com/company/product-science
# Company Link 2750: https://builtinla.com/company/spartan-radar-0
# Company Link 2751: https://builtinla.com/company/softswiss
# Company Link 2752: https://builtinla.com/company/stell-engineering
# Company Link 2753: https://builtinla.com/company/chargerhelp
# Company Link 2754: https://builtinla.com/company/pluto
# Company Link 2755: https://builtinla.com/company/artie
# Company Link 2756: https://builtinla.com/company/assembly-global
# Company Link 2757: https://builtinla.com/company/barsala
# Company Link 2758: https://builtinla.com/company/cencal-health
# Company Link 2759: https://builtinla.com/company/lightforce
# Company Link 2760: https://builtinla.com/company/mammoth-distribution
# Company Link 2761: https://builtinla.com/company/parallel-systems
# Company Link 2762: https://builtinla.com/company/sp6
# Company Link 2763: https://builtinla.com/company/terror-strikes
# Company Link 2764: https://builtinla.com/company/ateliers-gym
# Company Link 2765: https://builtinla.com/company/planeasy
# Company Link 2766: https://builtinla.com/company/coast-digital-0
# Company Link 2767: https://builtinla.com/company/bike-legal-firm
# Company Link 2768: https://builtinla.com/company/rypplzz
# Company Link 2769: https://builtinla.com/company/sam-and-colby
# Company Link 2770: https://builtinla.com/company/decktopus
# Company Link 2771: https://builtinla.com/company/impulse-space
# Company Link 2772: https://builtinla.com/company/atlas
# Company Link 2773: https://builtinla.com/company/arka-energy
# Company Link 2774: https://builtinla.com/company/gitai
# Company Link 2775: https://builtinla.com/company/crypto-advertising-0
# Company Link 2776: https://builtinla.com/company/bevz
# Company Link 2777: https://builtinla.com/company/complete-link-building-service-0
# Company Link 2778: https://builtinla.com/company/charlie-financial-services
# Company Link 2779: https://builtinla.com/company/patientfi
# Company Link 2780: https://builtinla.com/company/wells-group-new-york
# Company Link 2781: https://builtinla.com/node/154795
# Company Link 2782: https://builtinla.com/company/seedling
# Company Link 2783: https://builtinla.com/company/netdna
# Company Link 2784: https://builtinla.com/company/moxie-communications-group
# Company Link 2785: https://builtinla.com/company/beautycon-media
# Company Link 2786: https://builtinla.com/company/washio
# Company Link 2787: https://builtinla.com/company/startengine
# Company Link 2788: https://builtinla.com/company/airmap
# Company Link 2789: https://builtinla.com/company/convertro
# Company Link 2790: https://builtinla.com/company/headspace
# Company Link 2791: https://builtinla.com/company/adtaxi
# Company Link 2792: https://builtinla.com/company/lunya
# Company Link 2793: https://builtinla.com/company/mercy-animals
# Company Link 2794: https://builtinla.com/company/bottlenose
# Company Link 2795: https://builtinla.com/company/onprem
# Company Link 2796: https://builtinla.com/company/intelity
# Company Link 2797: https://builtinla.com/company/italist-inc
# Company Link 2798: https://builtinla.com/company/savingscom
# Company Link 2799: https://builtinla.com/company/pinwheel
# Company Link 2800: https://builtinla.com/company/industrious
# Company Link 2801: https://builtinla.com/company/futuredontics
# Company Link 2802: https://builtinla.com/company/velaro-incorporated
# Company Link 2803: https://builtinla.com/company/perfect-market-inc
# Company Link 2804: https://builtinla.com/company/pulled
# Company Link 2805: https://builtinla.com/company/versus-systems
# Company Link 2806: https://builtinla.com/company/codesmith
# Company Link 2807: https://builtinla.com/company/paysly
# Company Link 2808: https://builtinla.com/company/nationbuilder
# Company Link 2809: https://builtinla.com/company/motormood
# Company Link 2810: https://builtinla.com/company/havenly
# Company Link 2811: https://builtinla.com/company/spacex
# Company Link 2812: https://builtinla.com/company/gem
# Company Link 2813: https://builtinla.com/company/hello-giggles
# Company Link 2814: https://builtinla.com/company/listreports
# Company Link 2815: https://builtinla.com/company/influential
# Company Link 2816: https://builtinla.com/company/revolution-prep
# Company Link 2817: https://builtinla.com/company/anywr
# Company Link 2818: https://builtinla.com/company/hunker
# Company Link 2819: https://builtinla.com/company/eventene
# Company Link 2820: https://builtinla.com/company/maestroio
# Company Link 2821: https://builtinla.com/company/databudz
# Company Link 2822: https://builtinla.com/company/arrowroot-capital
# Company Link 2823: https://builtinla.com/company/pritzker-group-venture-capital
# Company Link 2824: https://builtinla.com/company/fox-digital-consumer-group
# Company Link 2825: https://builtinla.com/company/st-joseph-center-codetalk
# Company Link 2826: https://builtinla.com/company/genexa-inc
# Company Link 2827: https://builtinla.com/company/meltwater
# Company Link 2828: https://builtinla.com/company/obsidian-security
# Company Link 2829: https://builtinla.com/company/playstation-santa-monica
# Company Link 2830: https://builtinla.com/company/dealer-inspire
# Company Link 2831: https://builtinla.com/company/crosscut
# Company Link 2832: https://builtinla.com/company/fama-technologies
# Company Link 2833: https://builtinla.com/company/solid-commerce
# Company Link 2834: https://builtinla.com/company/tubescience
# Company Link 2835: https://builtinla.com/company/city-pasadena
# Company Link 2836: https://builtinla.com/company/iq-backoffice-inc
# Company Link 2837: https://builtinla.com/company/jackson-galaxy-enterprises
# Company Link 2838: https://builtinla.com/company/education-ecosystem
# Company Link 2839: https://builtinla.com/company/more-labs
# Company Link 2840: https://builtinla.com/company/knot-standard
# Company Link 2841: https://builtinla.com/company/universal-music-group
# Company Link 2842: https://builtinla.com/company/bliss-point-media
# Company Link 2843: https://builtinla.com/company/storyterrace-your-personal-biographer
# Company Link 2844: https://builtinla.com/company/arcules
# Company Link 2845: https://builtinla.com/company/upsellit
# Company Link 2846: https://builtinla.com/company/pariveda-solutions
# Company Link 2847: https://builtinla.com/company/loomly
# Company Link 2848: https://builtinla.com/company/techseshco
# Company Link 2849: https://builtinla.com/company/farm-project
# Company Link 2850: https://builtinla.com/company/reclip
# Company Link 2851: https://builtinla.com/company/cuddly
# Company Link 2852: https://builtinla.com/company/kleverdog-coworking
# Company Link 2853: https://builtinla.com/company/4wt-media
# Company Link 2854: https://builtinla.com/company/vonjour
# Company Link 2855: https://builtinla.com/company/younity
# Company Link 2856: https://builtinla.com/company/rocket-fuel-labs
# Company Link 2857: https://builtinla.com/company/be-great-partners
# Company Link 2858: https://builtinla.com/company/synosure-games-inc
# Company Link 2859: https://builtinla.com/company/instacanvas
# Company Link 2860: https://builtinla.com/company/siteport
# Company Link 2861: https://builtinla.com/company/tapatalk
# Company Link 2862: https://builtinla.com/company/playsino-0
# Company Link 2863: https://builtinla.com/company/idealab
# Company Link 2864: https://builtinla.com/company/assignmint
# Company Link 2865: https://builtinla.com/company/springrole
# Company Link 2866: https://builtinla.com/company/internshipscom
# Company Link 2867: https://builtinla.com/company/shoppingcartnet
# Company Link 2868: https://builtinla.com/company/zao
# Company Link 2869: https://builtinla.com/company/upfront-ventures
# Company Link 2870: https://builtinla.com/company/flashfunders
# Company Link 2871: https://builtinla.com/company/tape
# Company Link 2872: https://builtinla.com/company/givesurance
# Company Link 2873: https://builtinla.com/company/activity-club-app
# Company Link 2874: https://builtinla.com/company/cover-inc
# Company Link 2875: https://builtinla.com/company/studiotime
# Company Link 2876: https://builtinla.com/company/freedompop
# Company Link 2877: https://builtinla.com/company/wirecash
# Company Link 2878: https://builtinla.com/company/move-loot
# Company Link 2879: https://builtinla.com/company/access-integrated-healthcare
# Company Link 2880: https://builtinla.com/company/pumpic
# Company Link 2881: https://builtinla.com/company/indieu
# Company Link 2882: https://builtinla.com/company/erminesoft
# Company Link 2883: https://builtinla.com/company/rebel-ventures
# Company Link 2884: https://builtinla.com/company/betagig
# Company Link 2885: https://builtinla.com/company/fitscloud
# Company Link 2886: https://builtinla.com/company/easy-streak
# Company Link 2887: https://builtinla.com/company/thewavevr
# Company Link 2888: https://builtinla.com/company/rufus-labs
# Company Link 2889: https://builtinla.com/company/blurr
# Company Link 2890: https://builtinla.com/company/azubu
# Company Link 2891: https://builtinla.com/company/dreamscape-immersive
# Company Link 2892: https://builtinla.com/company/what-click-call
# Company Link 2893: https://builtinla.com/company/investedin
# Company Link 2894: https://builtinla.com/company/cofounderslab
# Company Link 2895: https://builtinla.com/company/break-media-0
# Company Link 2896: https://builtinla.com/company/wrent
# Company Link 2897: https://builtinla.com/company/agent-ace
# Company Link 2898: https://builtinla.com/company/o-labs
# Company Link 2899: https://builtinla.com/company/formative
# Company Link 2900: https://builtinla.com/company/voter
# Company Link 2901: https://builtinla.com/company/merry-jane-media
# Company Link 2902: https://builtinla.com/company/esportsinstructioncom
# Company Link 2903: https://builtinla.com/company/esl
# Company Link 2904: https://builtinla.com/company/nextbite
# Company Link 2905: https://builtinla.com/company/vokle
# Company Link 2906: https://builtinla.com/company/porter
# Company Link 2907: https://builtinla.com/company/privynet
# Company Link 2908: https://builtinla.com/company/generate-content-llc
# Company Link 2909: https://builtinla.com/company/yellowbot
# Company Link 2910: https://builtinla.com/company/sensay
# Company Link 2911: https://builtinla.com/company/kuapay
# Company Link 2912: https://builtinla.com/company/farmscape
# Company Link 2913: https://builtinla.com/company/greenhouse-go
# Company Link 2914: https://builtinla.com/company/tunepipe
# Company Link 2915: https://builtinla.com/company/augmented-reality-labs-0
# Company Link 2916: https://builtinla.com/company/leadferret
# Company Link 2917: https://builtinla.com/company/equator
# Company Link 2918: https://builtinla.com/company/equipois
# Company Link 2919: https://builtinla.com/company/everythinker
# Company Link 2920: https://builtinla.com/company/expensecloud
# Company Link 2921: https://builtinla.com/company/eye-interactive
# Company Link 2922: https://builtinla.com/company/addroid
# Company Link 2923: https://builtinla.com/company/fanlib
# Company Link 2924: https://builtinla.com/company/fantasy-world
# Company Link 2925: https://builtinla.com/company/covert-co
# Company Link 2926: https://builtinla.com/company/g2-media-network
# Company Link 2927: https://builtinla.com/company/bevvy
# Company Link 2928: https://builtinla.com/company/kwipster
# Company Link 2929: https://builtinla.com/company/biggerboat
# Company Link 2930: https://builtinla.com/company/langly
# Company Link 2931: https://builtinla.com/company/great-minds-design
# Company Link 2932: https://builtinla.com/company/burstly
# Company Link 2933: https://builtinla.com/company/ection
# Company Link 2934: https://builtinla.com/company/magento
# Company Link 2935: https://builtinla.com/company/headquarters-studios
# Company Link 2936: https://builtinla.com/company/capzles
# Company Link 2937: https://builtinla.com/company/emergent-game-technologies-inc
# Company Link 2938: https://builtinla.com/company/health-reach
# Company Link 2939: https://builtinla.com/company/peoplejar
# Company Link 2940: https://builtinla.com/company/petset
# Company Link 2941: https://builtinla.com/company/ghost-post
# Company Link 2942: https://builtinla.com/company/glydascope
# Company Link 2943: https://builtinla.com/company/go-social-now
# Company Link 2944: https://builtinla.com/company/brain-symphony
# Company Link 2945: https://builtinla.com/company/great-minds-design
# Company Link 2946: https://builtinla.com/company/ection
# Company Link 2947: https://builtinla.com/company/empedia
# Company Link 2948: https://builtinla.com/company/masher-media-inc
# Company Link 2949: https://builtinla.com/company/planjam
# Company Link 2950: https://builtinla.com/company/teeology
# Company Link 2951: https://builtinla.com/company/mmrglobal
# Company Link 2952: https://builtinla.com/company/playvuu
# Company Link 2953: https://builtinla.com/company/yummyyummytummy
# Company Link 2954: https://builtinla.com/company/tapit
# Company Link 2955: https://builtinla.com/company/appnrg
# Company Link 2956: https://builtinla.com/company/qweboo
# Company Link 2957: https://builtinla.com/company/clearpath-networks
# Company Link 2958: https://builtinla.com/company/infillion
# Company Link 2959: https://builtinla.com/company/rednook
# Company Link 2960: https://builtinla.com/company/targetclose
# Company Link 2961: https://builtinla.com/company/setkick
# Company Link 2962: https://builtinla.com/company/venlabs
# Company Link 2963: https://builtinla.com/company/singlepine
# Company Link 2964: https://builtinla.com/company/socialstay
# Company Link 2965: https://builtinla.com/company/gether-0
# Company Link 2966: https://builtinla.com/company/periodical-co
# Company Link 2967: https://builtinla.com/company/tymelinx
# Company Link 2968: https://builtinla.com/company/tried-true-tutoring
# Company Link 2969: https://builtinla.com/company/vidappe
# Company Link 2970: https://builtinla.com/company/top-bargains
# Company Link 2971: https://builtinla.com/company/mariposa-capital-management-llc
# Company Link 2972: https://builtinla.com/company/weplay
# Company Link 2973: https://builtinla.com/company/pulsecaster
# Company Link 2974: https://builtinla.com/company/launchflow
# Company Link 2975: https://builtinla.com/company/switch-i-save
# Company Link 2976: https://builtinla.com/company/letsgodoit
# Company Link 2977: https://builtinla.com/company/filmzu
# Company Link 2978: https://builtinla.com/company/trexa
# Company Link 2979: https://builtinla.com/company/ad-touch
# Company Link 2980: https://builtinla.com/company/tildeworks
# Company Link 2981: https://builtinla.com/company/kudo-learning
# Company Link 2982: https://builtinla.com/company/clover
# Company Link 2983: https://builtinla.com/company/attendify
# Company Link 2984: https://builtinla.com/company/icebox-inc
# Company Link 2985: https://builtinla.com/company/haul
# Company Link 2986: https://builtinla.com/company/ivee
# Company Link 2987: https://builtinla.com/company/copii
# Company Link 2988: https://builtinla.com/company/sprokk
# Company Link 2989: https://builtinla.com/company/track-social
# Company Link 2990: https://builtinla.com/company/drinks-me-tonight
# Company Link 2991: https://builtinla.com/company/dynamic-synergy-executive-recruitment
# Company Link 2992: https://builtinla.com/company/rightsify
# Company Link 2993: https://builtinla.com/company/pickfu
# Company Link 2994: https://builtinla.com/company/society6
# Company Link 2995: https://builtinla.com/company/chowsome
# Company Link 2996: https://builtinla.com/company/shoplately
# Company Link 2997: https://builtinla.com/company/addioncom
# Company Link 2998: https://builtinla.com/company/16th-bar
# Company Link 2999: https://builtinla.com/company/riplio-inc
# Company Link 3000: https://builtinla.com/company/greentoe
# Company Link 3001: https://builtinla.com/company/district2co
# Company Link 3002: https://builtinla.com/company/zendyhealth
# Company Link 3003: https://builtinla.com/company/clout
# Company Link 3004: https://builtinla.com/company/vipehype
# Company Link 3005: https://builtinla.com/company/prizeo
# Company Link 3006: https://builtinla.com/company/extradenaire
# Company Link 3007: https://builtinla.com/company/haulr
# Company Link 3008: https://builtinla.com/company/kwaai-oak
# Company Link 3009: https://builtinla.com/company/plumm
# Company Link 3010: https://builtinla.com/company/elephantdrive-0
# Company Link 3011: https://builtinla.com/company/seomator
# Company Link 3012: https://builtinla.com/company/zeconomy
# Company Link 3013: https://builtinla.com/company/deliveer
# Company Link 3014: https://builtinla.com/company/datascoops
# Company Link 3015: https://builtinla.com/company/demandlayer
# Company Link 3016: https://builtinla.com/company/blinkbop
# Company Link 3017: https://builtinla.com/company/fingertip-maestro-music-app
# Company Link 3018: https://builtinla.com/company/maison-row
# Company Link 3019: https://builtinla.com/company/chargebee
# Company Link 3020: https://builtinla.com/company/kohr
# Company Link 3021: https://builtinla.com/company/eventap
# Company Link 3022: https://builtinla.com/company/social-board
# Company Link 3023: https://builtinla.com/company/wiredrive
# Company Link 3024: https://builtinla.com/company/ueis
# Company Link 3025: https://builtinla.com/company/force-impact-technologies
# Company Link 3026: https://builtinla.com/company/yeti
# Company Link 3027: https://builtinla.com/company/overland-remodeling-builders
# Company Link 3028: https://builtinla.com/company/little-arrows
# Company Link 3029: https://builtinla.com/company/national-produce-exchange
# Company Link 3030: https://builtinla.com/company/lyka
# Company Link 3031: https://builtinla.com/company/wype
# Company Link 3032: https://builtinla.com/company/ozobot
# Company Link 3033: https://builtinla.com/company/yapstone
# Company Link 3034: https://builtinla.com/company/trepscore
# Company Link 3035: https://builtinla.com/company/global-merchant-advisors
# Company Link 3036: https://builtinla.com/company/my-creative-mark
# Company Link 3037: https://builtinla.com/company/bannerman
# Company Link 3038: https://builtinla.com/company/idean
# Company Link 3039: https://builtinla.com/company/pivotal-labs
# Company Link 3040: https://builtinla.com/company/glamstand-inc
# Company Link 3041: https://builtinla.com/company/exit-monitor
# Company Link 3042: https://builtinla.com/company/fund-dreamer
# Company Link 3043: https://builtinla.com/company/hofb
# Company Link 3044: https://builtinla.com/company/ez-ad-tv
# Company Link 3045: https://builtinla.com/company/renewu
# Company Link 3046: https://builtinla.com/company/dials
# Company Link 3047: https://builtinla.com/company/beach-mobile
# Company Link 3048: https://builtinla.com/company/sage-design-group
# Company Link 3049: https://builtinla.com/company/adtoapp
# Company Link 3050: https://builtinla.com/company/bldup
# Company Link 3051: https://builtinla.com/company/belkin-international
# Company Link 3052: https://builtinla.com/company/berenji-associates
# Company Link 3053: https://builtinla.com/company/service
# Company Link 3054: https://builtinla.com/company/fairhead-creative-llc
# Company Link 3055: https://builtinla.com/company/socratica-llc
# Company Link 3056: https://builtinla.com/company/emailchopper
# Company Link 3057: https://builtinla.com/company/homeunion
# Company Link 3058: https://builtinla.com/company/headquarters-hq
# Company Link 3059: https://builtinla.com/company/mr-pdf-editor-edit-pdf-documents-pdf-word-pdf-forms-business
# Company Link 3060: https://builtinla.com/company/all-hart-media
# Company Link 3061: https://builtinla.com/company/fund-dreamer-1
# Company Link 3062: https://builtinla.com/company/trust-sourcing
# Company Link 3063: https://builtinla.com/company/pitch-training-camp
# Company Link 3064: https://builtinla.com/company/mimeo-labs
# Company Link 3065: https://builtinla.com/company/bkstg
# Company Link 3066: https://builtinla.com/company/mighty-networks
# Company Link 3067: https://builtinla.com/company/sage-design-group
# Company Link 3068: https://builtinla.com/company/intooxyz
# Company Link 3069: https://builtinla.com/company/designersaxis
# Company Link 3070: https://builtinla.com/company/bruu-vending
# Company Link 3071: https://builtinla.com/company/natuza
# Company Link 3072: https://builtinla.com/company/loannow
# Company Link 3073: https://builtinla.com/company/zonetail
# Company Link 3074: https://builtinla.com/company/h2-wellness
# Company Link 3075: https://builtinla.com/company/healthlinerx
# Company Link 3076: https://builtinla.com/company/mr-pdf-editor-edit-pdf-documents-pdf-word-pdf-forms-business
# Company Link 3077: https://builtinla.com/company/jstar-llc
# Company Link 3078: https://builtinla.com/company/pacific-issue
# Company Link 3079: https://builtinla.com/company/designpaxcom
# Company Link 3080: https://builtinla.com/company/codejects
# Company Link 3081: https://builtinla.com/company/liveadmins
# Company Link 3082: https://builtinla.com/company/illuminate-education
# Company Link 3083: https://builtinla.com/company/bookingpal
# Company Link 3084: https://builtinla.com/company/aumcore
# Company Link 3085: https://builtinla.com/company/my-mobile-watchdog
# Company Link 3086: https://builtinla.com/company/ezer-delivery
# Company Link 3087: https://builtinla.com/company/smartypants-vitamins
# Company Link 3088: https://builtinla.com/company/oceanx
# Company Link 3089: https://builtinla.com/company/medmen
# Company Link 3090: https://builtinla.com/company/renly
# Company Link 3091: https://builtinla.com/company/reikit
# Company Link 3092: https://builtinla.com/company/launch-mobility
# Company Link 3093: https://builtinla.com/company/clicktripz
# Company Link 3094: https://builtinla.com/company/growthhackers
# Company Link 3095: https://builtinla.com/company/fastdataio
# Company Link 3096: https://builtinla.com/company/reely
# Company Link 3097: https://builtinla.com/company/kindmanage
# Company Link 3098: https://builtinla.com/company/eta-compute
# Company Link 3099: https://builtinla.com/company/e-man-labs
# Company Link 3100: https://builtinla.com/company/lantronix
# Company Link 3101: https://builtinla.com/company/ignitedspaces
# Company Link 3102: https://builtinla.com/company/peplworks
# Company Link 3103: https://builtinla.com/company/partiac
# Company Link 3104: https://builtinla.com/company/lola
# Company Link 3105: https://builtinla.com/company/patient-insights
# Company Link 3106: https://builtinla.com/company/botana
# Company Link 3107: https://builtinla.com/company/sachs-marketing-group
# Company Link 3108: https://builtinla.com/company/dotty
# Company Link 3109: https://builtinla.com/company/faye-business-group-fayebsg
# Company Link 3110: https://builtinla.com/company/trace3
# Company Link 3111: https://builtinla.com/company/secured-retail-networks
# Company Link 3112: https://builtinla.com/company/meta
# Company Link 3113: https://builtinla.com/company/baby-box-co
# Company Link 3114: https://builtinla.com/company/11-honore
# Company Link 3115: https://builtinla.com/company/cubicall-0
# Company Link 3116: https://builtinla.com/company/echat
# Company Link 3117: https://builtinla.com/company/adzap
# Company Link 3118: https://builtinla.com/company/agrisaurus
# Company Link 3119: https://builtinla.com/company/catch-media
# Company Link 3120: https://builtinla.com/company/cinecause
# Company Link 3121: https://builtinla.com/company/clorder
# Company Link 3122: https://builtinla.com/company/crowd-seats
# Company Link 3123: https://builtinla.com/company/deluxis
# Company Link 3124: https://builtinla.com/company/digitilus
# Company Link 3125: https://builtinla.com/company/everysignal
# Company Link 3126: https://builtinla.com/company/ideamensch
# Company Link 3127: https://builtinla.com/company/kindspark
# Company Link 3128: https://builtinla.com/company/lowermybills
# Company Link 3129: https://builtinla.com/company/lrn-corp
# Company Link 3130: https://builtinla.com/company/market-wire
# Company Link 3131: https://builtinla.com/company/momassembly
# Company Link 3132: https://builtinla.com/company/nojuice
# Company Link 3133: https://builtinla.com/company/opposing-views-inc
# Company Link 3134: https://builtinla.com/company/revver
# Company Link 3135: https://builtinla.com/company/rooomr
# Company Link 3136: https://builtinla.com/company/vivotrak
# Company Link 3137: https://builtinla.com/company/waitscout
# Company Link 3138: https://builtinla.com/company/zo-creative
# Company Link 3139: https://builtinla.com/company/look-io
# Company Link 3140: https://builtinla.com/company/docuspeak
# Company Link 3141: https://builtinla.com/company/wilshire-hosting
# Company Link 3142: https://builtinla.com/company/nomatron
# Company Link 3143: https://builtinla.com/company/cureia-medical
# Company Link 3144: https://builtinla.com/company/easier-softer-way-0
# Company Link 3145: https://builtinla.com/company/dimension-5-media
# Company Link 3146: https://builtinla.com/company/furca-media
# Company Link 3147: https://builtinla.com/company/wishee
# Company Link 3148: https://builtinla.com/company/tiescom-scarvescom
# Company Link 3149: https://builtinla.com/company/iso-genie
# Company Link 3150: https://builtinla.com/company/placety
# Company Link 3151: https://builtinla.com/company/way-easy-gifts
# Company Link 3152: https://builtinla.com/company/mother-company
# Company Link 3153: https://builtinla.com/company/startuptoolshop
# Company Link 3154: https://builtinla.com/company/cliqmaps
# Company Link 3155: https://builtinla.com/company/want
# Company Link 3156: https://builtinla.com/company/donation-location
# Company Link 3157: https://builtinla.com/company/connective-magic
# Company Link 3158: https://builtinla.com/company/peggd
# Company Link 3159: https://builtinla.com/company/agentbridge
# Company Link 3160: https://builtinla.com/company/pwnit
# Company Link 3161: https://builtinla.com/company/eurisko-mobility
# Company Link 3162: https://builtinla.com/company/invisible-text
# Company Link 3163: https://builtinla.com/company/fina-v-capital
# Company Link 3164: https://builtinla.com/company/gotokki-inc
# Company Link 3165: https://builtinla.com/company/xgear
# Company Link 3166: https://builtinla.com/company/mylab
# Company Link 3167: https://builtinla.com/company/bettertrainers
# Company Link 3168: https://builtinla.com/company/taggle
# Company Link 3169: https://builtinla.com/company/general-specific-inc
# Company Link 3170: https://builtinla.com/company/radius-pop
# Company Link 3171: https://builtinla.com/company/pladdow
# Company Link 3172: https://builtinla.com/company/hothop
# Company Link 3173: https://builtinla.com/company/agreed-escrow-inc
# Company Link 3174: https://builtinla.com/company/stillwater-media-group
# Company Link 3175: https://builtinla.com/company/cinq-music
# Company Link 3176: https://builtinla.com/company/vidme
# Company Link 3177: https://builtinla.com/company/red-beach-advisors
# Company Link 3178: https://builtinla.com/company/buckitdream
# Company Link 3179: https://builtinla.com/company/mindera
# Company Link 3180: https://builtinla.com/company/digitour-media
# Company Link 3181: https://builtinla.com/company/representxyz
# Company Link 3182: https://builtinla.com/company/spinx-digital
# Company Link 3183: https://builtinla.com/company/openmethods
# Company Link 3184: https://builtinla.com/company/bimatoproststore-online-pharmacy
# Company Link 3185: https://builtinla.com/company/ridit
# Company Link 3186: https://builtinla.com/company/vizzario
# Company Link 3187: https://builtinla.com/company/travoomcom
# Company Link 3188: https://builtinla.com/company/caa-ventures
# Company Link 3189: https://builtinla.com/company/babyation
# Company Link 3190: https://builtinla.com/company/ev-connect
# Company Link 3191: https://builtinla.com/company/raistone-inc
# Company Link 3192: https://builtinla.com/company/zya
# Company Link 3193: https://builtinla.com/company/1courier
# Company Link 3194: https://builtinla.com/company/suitely
# Company Link 3195: https://builtinla.com/company/pixologic
# Company Link 3196: https://builtinla.com/company/milk-and-eggs
# Company Link 3197: https://builtinla.com/company/oracle
# Company Link 3198: https://builtinla.com/company/rideamigos
# Company Link 3199: https://builtinla.com/company/represent
# Company Link 3200: https://builtinla.com/company/mophie
# Company Link 3201: https://builtinla.com/company/icclarity
# Company Link 3202: https://builtinla.com/company/pixsweet
# Company Link 3203: https://builtinla.com/company/yepchat
# Company Link 3204: https://builtinla.com/company/guesty
# Company Link 3205: https://builtinla.com/company/boring-company
# Company Link 3206: https://builtinla.com/company/prescribewellness
# Company Link 3207: https://builtinla.com/company/hackreactor-0
# Company Link 3208: https://builtinla.com/company/activision
# Company Link 3209: https://builtinla.com/company/pex
# Company Link 3210: https://builtinla.com/company/dosist
# Company Link 3211: https://builtinla.com/company/servie
# Company Link 3212: https://builtinla.com/company/instantgo
# Company Link 3213: https://builtinla.com/company/civicfeed
# Company Link 3214: https://builtinla.com/company/pcloudy
# Company Link 3215: https://builtinla.com/company/shade-store
# Company Link 3216: https://builtinla.com/company/lumzag
# Company Link 3217: https://builtinla.com/company/conversionpoint-technologies
# Company Link 3218: https://builtinla.com/company/polymail
# Company Link 3219: https://builtinla.com/company/revzi
# Company Link 3220: https://builtinla.com/company/dreamworks-animation
# Company Link 3221: https://builtinla.com/company/togoelectro
# Company Link 3222: https://builtinla.com/company/company-vakil
# Company Link 3223: https://builtinla.com/company/recharge-designs
# Company Link 3224: https://builtinla.com/company/leaseful
# Company Link 3225: https://builtinla.com/company/hostbooks
# Company Link 3226: https://builtinla.com/company/next-american-media-makers
# Company Link 3227: https://builtinla.com/company/avisare-0
# Company Link 3228: https://builtinla.com/company/tenantbase
# Company Link 3229: https://builtinla.com/company/inkjetscom
# Company Link 3230: https://builtinla.com/company/netcloak
# Company Link 3231: https://builtinla.com/company/go-away
# Company Link 3232: https://builtinla.com/company/scalelab
# Company Link 3233: https://builtinla.com/company/juicer
# Company Link 3234: https://builtinla.com/company/310-creative
# Company Link 3235: https://builtinla.com/company/edo
# Company Link 3236: https://builtinla.com/company/wellth
# Company Link 3237: https://builtinla.com/company/touchstone-analytics
# Company Link 3238: https://builtinla.com/company/taxi-pulse
# Company Link 3239: https://builtinla.com/company/your-super
# Company Link 3240: https://builtinla.com/company/vresh
# Company Link 3241: https://builtinla.com/company/revolutioncredit
# Company Link 3242: https://builtinla.com/company/aris
# Company Link 3243: https://builtinla.com/company/qlogic
# Company Link 3244: https://builtinla.com/company/curatedseotoolscom
# Company Link 3245: https://builtinla.com/company/hellosociety
# Company Link 3246: https://builtinla.com/company/filterpop
# Company Link 3247: https://builtinla.com/company/turnoutt
# Company Link 3248: https://builtinla.com/company/casopia-0
# Company Link 3249: https://builtinla.com/company/sonic-faction
# Company Link 3250: https://builtinla.com/company/cyclehop
# Company Link 3251: https://builtinla.com/company/freightpal
# Company Link 3252: https://builtinla.com/company/food-tribe
# Company Link 3253: https://builtinla.com/company/roli
# Company Link 3254: https://builtinla.com/company/kicktack
# Company Link 3255: https://builtinla.com/company/hackreactor-0
# Company Link 3256: https://builtinla.com/company/cinematique
# Company Link 3257: https://builtinla.com/company/iam
# Company Link 3258: https://builtinla.com/company/otherworld-interactive
# Company Link 3259: https://builtinla.com/company/first-contact-entertainment
# Company Link 3260: https://builtinla.com/company/smokeball
# Company Link 3261: https://builtinla.com/company/songtradr-0
# Company Link 3262: https://builtinla.com/company/peoplescape-search
# Company Link 3263: https://builtinla.com/company/avinew
# Company Link 3264: https://builtinla.com/company/global-technology-users
# Company Link 3265: https://builtinla.com/company/potster
# Company Link 3266: https://builtinla.com/company/kwikse-0
# Company Link 3267: https://builtinla.com/company/swift-health-sytems-inc-dba-inbrace
# Company Link 3268: https://builtinla.com/company/instaco
# Company Link 3269: https://builtinla.com/company/simpaul-design
# Company Link 3270: https://builtinla.com/company/bigger-hammer-production-services
# Company Link 3271: https://builtinla.com/company/remotelock
# Company Link 3272: https://builtinla.com/company/er-snell-contractor-inc
# Company Link 3273: https://builtinla.com/company/mattressjack
# Company Link 3274: https://builtinla.com/company/search-partners-recruiting
# Company Link 3275: https://builtinla.com/company/event-hub
# Company Link 3276: https://builtinla.com/company/dmai
# Company Link 3277: https://builtinla.com/company/mindster
# Company Link 3278: https://builtinla.com/company/cryptosoftwares
# Company Link 3279: https://builtinla.com/company/gamebench
# Company Link 3280: https://builtinla.com/company/transplant-connect
# Company Link 3281: https://builtinla.com/company/createtribe
# Company Link 3282: https://builtinla.com/company/dumont-project
# Company Link 3283: https://builtinla.com/company/miku-inc
# Company Link 3284: https://builtinla.com/company/brand-incubator
# Company Link 3285: https://builtinla.com/company/laylo
# Company Link 3286: https://builtinla.com/company/kinestry
# Company Link 3287: https://builtinla.com/company/momentum-iot
# Company Link 3288: https://builtinla.com/company/myroofingpal
# Company Link 3289: https://builtinla.com/company/exela-technologies
# Company Link 3290: https://builtinla.com/company/algopay
# Company Link 3291: https://builtinla.com/company/proguides
# Company Link 3292: https://builtinla.com/company/orfium
# Company Link 3293: https://builtinla.com/company/poway-cleaning-club
# Company Link 3294: https://builtinla.com/company/techstyleos
# Company Link 3295: https://builtinla.com/company/jazva
# Company Link 3296: https://builtinla.com/company/panoramic
# Company Link 3297: https://builtinla.com/company/podcorn
# Company Link 3298: https://builtinla.com/company/murad
# Company Link 3299: https://builtinla.com/company/livelist
# Company Link 3300: https://builtinla.com/company/torrid
# Company Link 3301: https://builtinla.com/company/forge-platform
# Company Link 3302: https://builtinla.com/company/jib-jab
# Company Link 3303: https://builtinla.com/company/diffusion-pr
# Company Link 3304: https://builtinla.com/company/tiktok
# Company Link 3305: https://builtinla.com/company/voyage-sms
# Company Link 3306: https://builtinla.com/company/issuance
# Company Link 3307: https://builtinla.com/company/flowspace
# Company Link 3308: https://builtinla.com/company/relocity
# Company Link 3309: https://builtinla.com/company/10techdesign
# Company Link 3310: https://builtinla.com/company/canoo
# Company Link 3311: https://builtinla.com/company/postie-inc
# Company Link 3312: https://builtinla.com/company/clickoo
# Company Link 3313: https://builtinla.com/company/swift-health-system-inc-dba-inbrace
# Company Link 3314: https://builtinla.com/company/sling-stone
# Company Link 3315: https://builtinla.com/company/optin-contacts-inc
# Company Link 3316: https://builtinla.com/company/pangaea
# Company Link 3317: https://builtinla.com/company/spin-scooters
# Company Link 3318: https://builtinla.com/company/panoraven
# Company Link 3319: https://builtinla.com/company/chromadex
# Company Link 3320: https://builtinla.com/company/dmai
# Company Link 3321: https://builtinla.com/company/manufactured
# Company Link 3322: https://builtinla.com/company/qos-networks
# Company Link 3323: https://builtinla.com/company/steady-app
# Company Link 3324: https://builtinla.com/company/la-seo-service
# Company Link 3325: https://builtinla.com/company/pixelogic-media
# Company Link 3326: https://builtinla.com/company/create-wiki-page
# Company Link 3327: https://builtinla.com/company/mmgy-global
# Company Link 3328: https://builtinla.com/company/spin-master
# Company Link 3329: https://builtinla.com/company/simplyafterschool
# Company Link 3330: https://builtinla.com/company/margasoft-corp
# Company Link 3331: https://builtinla.com/company/telescope-inc
# Company Link 3332: https://builtinla.com/company/levelplay-sports
# Company Link 3333: https://builtinla.com/company/santa-monica-studio
# Company Link 3334: https://builtinla.com/company/unreel-entertainment
# Company Link 3335: https://builtinla.com/company/loansnap
# Company Link 3336: https://builtinla.com/company/halo-top-creamery
# Company Link 3337: https://builtinla.com/company/airespring
# Company Link 3338: https://builtinla.com/company/servoy
# Company Link 3339: https://builtinla.com/company/startpage
# Company Link 3340: https://builtinla.com/company/bruin-biometrics-llc
# Company Link 3341: https://builtinla.com/company/red-butler
# Company Link 3342: https://builtinla.com/company/prime-clinical-systems
# Company Link 3343: https://builtinla.com/company/access-networks
# Company Link 3344: https://builtinla.com/company/cloudkitchens-0
# Company Link 3345: https://builtinla.com/company/gif-your-game
# Company Link 3346: https://builtinla.com/company/taproot-foundation
# Company Link 3347: https://builtinla.com/company/ringer
# Company Link 3348: https://builtinla.com/company/iolo-technologies
# Company Link 3349: https://builtinla.com/company/brand-ventures-inc-brandedofferscom
# Company Link 3350: https://builtinla.com/company/mode2
# Company Link 3351: https://builtinla.com/company/onica
# Company Link 3352: https://builtinla.com/company/blue-jeans
# Company Link 3353: https://builtinla.com/company/murphy-research
# Company Link 3354: https://builtinla.com/company/voyage-mobile
# Company Link 3355: https://builtinla.com/company/biostrap
# Company Link 3356: https://builtinla.com/company/yobs-technologies
# Company Link 3357: https://builtinla.com/company/tonik
# Company Link 3358: https://builtinla.com/company/californly
# Company Link 3359: https://builtinla.com/company/gorilla-design-lab
# Company Link 3360: https://builtinla.com/company/los-angeles-design-studio
# Company Link 3361: https://builtinla.com/company/becore
# Company Link 3362: https://builtinla.com/company/til-events
# Company Link 3363: https://builtinla.com/company/dev-masters
# Company Link 3364: https://builtinla.com/company/brainstation
# Company Link 3365: https://builtinla.com/company/pluralsight
# Company Link 3366: https://builtinla.com/company/hackedu
# Company Link 3367: https://builtinla.com/company/airgarage
# Company Link 3368: https://builtinla.com/company/loop
# Company Link 3369: https://builtinla.com/company/bodewell
# Company Link 3370: https://builtinla.com/company/designlab
# Company Link 3371: https://builtinla.com/company/i3dnet-llc
# Company Link 3372: https://builtinla.com/company/landline-company
# Company Link 3373: https://builtinla.com/company/equitybee
# Company Link 3374: https://builtinla.com/company/advanced-nurse-practitioner-jobs
# Company Link 3375: https://builtinla.com/company/buildops
# Company Link 3376: https://builtinla.com/company/webclues-infotech
# Company Link 3377: https://builtinla.com/company/digital-unicorn
# Company Link 3378: https://builtinla.com/company/liquidata
# Company Link 3379: https://builtinla.com/company/nacelle
# Company Link 3380: https://builtinla.com/company/mymo-mochi-ice-cream
# Company Link 3381: https://builtinla.com/company/opus9
# Company Link 3382: https://builtinla.com/company/way2smile-solutions-dmcc
# Company Link 3383: https://builtinla.com/company/yoni-circle
# Company Link 3384: https://builtinla.com/company/embodied-labs
# Company Link 3385: https://builtinla.com/company/unita
# Company Link 3386: https://builtinla.com/company/limitless-renovations
# Company Link 3387: https://builtinla.com/company/sketcher
# Company Link 3388: https://builtinla.com/company/true-vision
# Company Link 3389: https://builtinla.com/company/los-angeles-times
# Company Link 3390: https://builtinla.com/company/tangogg
# Company Link 3391: https://builtinla.com/company/robin-games
# Company Link 3392: https://builtinla.com/company/bioiq
# Company Link 3393: https://builtinla.com/company/basil-street
# Company Link 3394: https://builtinla.com/company/snappt
# Company Link 3395: https://builtinla.com/company/urgentpoint-inc
# Company Link 3396: https://builtinla.com/company/sure-vision-glasses
# Company Link 3397: https://builtinla.com/company/kippo
# Company Link 3398: https://builtinla.com/company/insperience
# Company Link 3399: https://builtinla.com/company/lucid-circuit-inc
# Company Link 3400: https://builtinla.com/company/audigo-labs
# Company Link 3401: https://builtinla.com/company/jel-tech-llc
# Company Link 3402: https://builtinla.com/company/zform
# Company Link 3403: https://builtinla.com/company/after-hours-surgical-care-llc
# Company Link 3404: https://builtinla.com/company/grove
# Company Link 3405: https://builtinla.com/company/wave-sports-entertainment
# Company Link 3406: https://builtinla.com/company/radixweb
# Company Link 3407: https://builtinla.com/company/marketerhire-archived-2022-01-20
# Company Link 3408: https://builtinla.com/company/newegg
# Company Link 3409: https://builtinla.com/company/tobe-agency
# Company Link 3410: https://builtinla.com/company/parentsquare
# Company Link 3411: https://builtinla.com/company/motorenn
# Company Link 3412: https://builtinla.com/company/manime
# Company Link 3413: https://builtinla.com/company/pyng-community-messaging
# Company Link 3414: https://builtinla.com/company/livekindly
# Company Link 3415: https://builtinla.com/company/sbly
# Company Link 3416: https://builtinla.com/company/shim-shack
# Company Link 3417: https://builtinla.com/company/del-pacifico-restaurant-1
# Company Link 3418: https://builtinla.com/company/gr0
# Company Link 3419: https://builtinla.com/company/avention-media
# ...
# Company Link 7388: https://builtinla.com/company/rootstrap
# Company Link 7389: https://builtinla.com/company/xcentium
# Company Link 7390: https://builtinla.com/company/greenspire
# Company Link 7391: https://builtinla.com/company/rxvantage
# Company Link 7392: https://builtinla.com/company/hummly
# Company Link 7393: https://builtinla.com/company/blaze
# Company Link 7394: https://builtinla.com/company/mycrew
# Company Link 7395: https://builtinla.com/company/hykso
# Company Link 7396: https://builtinla.com/company/neudesic
# Company Link 7397: https://builtinla.com/company/sphynx
# Company Link 7398: https://builtinla.com/company/trigger-xr
# Company Link 7399: https://builtinla.com/company/music-audience-exchange
# Company Link 7400: https://builtinla.com/company/invibe
# Company Link 7401: https://builtinla.com/company/adero
# Company Link 7402: https://builtinla.com/company/nhn
# Company Link 7403: https://builtinla.com/company/one-step-software
# Company Link 7404: https://builtinla.com/company/airfind
# Company Link 7405: https://builtinla.com/company/appliedvr
# Company Link 7406: https://builtinla.com/company/hello-design
# Company Link 7407: https://builtinla.com/company/studio-71
# Company Link 7408: https://builtinla.com/company/do-lab
# Company Link 7409: https://builtinla.com/company/predictive-index
# Company Link 7410: https://builtinla.com/company/evolv-technology
# Company Link 7411: https://builtinla.com/company/doubleverify
# Company Link 7412: https://builtinla.com/company/resy
# Company Link 7413: https://builtinla.com/company/knotch
# Company Link 7414: https://builtinla.com/company/chive-media-group
# Company Link 7415: https://builtinla.com/company/motorcar-parts-america
# Company Link 7416: https://builtinla.com/company/wash-multifamily-laundry-systems
# Company Link 7417: https://builtinla.com/company/icertis
# Company Link 7418: https://builtinla.com/company/lionsgate-films
# Company Link 7419: https://builtinla.com/company/expedia
# Company Link 7420: https://builtinla.com/company/joor
# Company Link 7421: https://builtinla.com/company/bluemark
# Company Link 7422: https://builtinla.com/company/epoch-universal-inc
# Company Link 7423: https://builtinla.com/company/new-american-funding
# Company Link 7424: https://builtinla.com/company/pushpay
# Company Link 7425: https://builtinla.com/company/leafly
# Company Link 7426: https://builtinla.com/company/rivian
# Company Link 7427: https://builtinla.com/company/supercool-creative-agency
# Company Link 7428: https://builtinla.com/company/kitchen-united-inc-0
# Company Link 7429: https://builtinla.com/company/brandastic
# Company Link 7430: https://builtinla.com/company/nodabl
# Company Link 7431: https://builtinla.com/company/space150
# Company Link 7432: https://builtinla.com/company/mitos-technologies
# Company Link 7433: https://builtinla.com/company/konnect-agency
# Company Link 7434: https://builtinla.com/company/evvemi
# Company Link 7435: https://builtinla.com/company/tic-toc-games
# Company Link 7436: https://builtinla.com/company/agent-image
# Company Link 7437: https://builtinla.com/company/wagstaff-worldwide
# Company Link 7438: https://builtinla.com/company/implementek
# Company Link 7439: https://builtinla.com/company/reaction-commerce
# Company Link 7440: https://builtinla.com/company/eisneramper
# Company Link 7441: https://builtinla.com/company/izi-benne-location-benne-en-france
# Company Link 7442: https://builtinla.com/company/built-blank-0
# Company Link 7443: https://builtinla.com/company/kelton-global
# Company Link 7444: https://builtinla.com/company/wagstaff-worldwide
# Company Link 7445: https://builtinla.com/company/cargofy
# Company Link 7446: https://builtinla.com/company/onzie-yoga-apparel
# Company Link 7447: https://builtinla.com/company/skoruz-technologies
# Company Link 7448: https://builtinla.com/company/pricespider
# Company Link 7449: https://builtinla.com/company/biostrap
# Company Link 7450: https://builtinla.com/company/mewe
# Company Link 7451: https://builtinla.com/company/greensolar-technologies
# Company Link 7452: https://builtinla.com/company/international-checkout-inc
# Company Link 7453: https://builtinla.com/company/endertech
# Company Link 7454: https://builtinla.com/company/use-all-five
# Company Link 7455: https://builtinla.com/company/vrrb
# Company Link 7456: https://builtinla.com/company/life-elements
# Company Link 7457: https://builtinla.com/company/nice-studios
# Company Link 7458: https://builtinla.com/company/nrg-experiential
# Company Link 7459: https://builtinla.com/company/glofox-1
# Company Link 7460: https://builtinla.com/company/beekeepers-naturals
# Company Link 7461: https://builtinla.com/company/labrador-systems
# Company Link 7462: https://builtinla.com/company/frameio
# Company Link 7463: https://builtinla.com/company/registered-general-nurse-jobs
# Company Link 7464: https://builtinla.com/company/fightcamp
# Company Link 7465: https://builtinla.com/company/bizinfor
# Company Link 7466: https://builtinla.com/company/resilientheart
# Company Link 7467: https://builtinla.com/company/sygnio-inc
# Company Link 7468: https://builtinla.com/company/epixel-solutions-llc
# Company Link 7469: https://builtinla.com/company/spike-media-inc
# Company Link 7470: https://builtinla.com/company/cli-studios
# Company Link 7471: https://builtinla.com/company/charming-charlie
# Company Link 7472: https://builtinla.com/company/eisenhower-health-careers
# Company Link 7473: https://builtinla.com/company/kantar-media
# Company Link 7474: https://builtinla.com/company/blackberry
# Company Link 7475: https://builtinla.com/company/wondery-0
# Company Link 7476: https://builtinla.com/company/copyrights-protection-bureau-uk
# Company Link 7477: https://builtinla.com/company/bioiq
# Company Link 7478: https://builtinla.com/company/software-finder
# Company Link 7479: https://builtinla.com/company/tpirc-southern-california-food-allergy-institute
# Company Link 7480: https://builtinla.com/company/cinedapt
# Company Link 7481: https://builtinla.com/company/lucid-circuit-inc
# Company Link 7482: https://builtinla.com/company/audigo-labs
# Company Link 7483: https://builtinla.com/company/dd
# Company Link 7484: https://builtinla.com/company/after-hours-surgical-care-llc
# Company Link 7485: https://builtinla.com/company/storied
# Company Link 7486: https://builtinla.com/company/mesh
# Company Link 7487: https://builtinla.com/company/power-inspires-progress
# Company Link 7488: https://builtinla.com/company/aiva-health
# Company Link 7489: https://builtinla.com/company/marketerhire-archived-2022-01-20
# Company Link 7490: https://builtinla.com/company/rethink-software
# Company Link 7491: https://builtinla.com/company/robyn
# Company Link 7492: https://builtinla.com/company/indian-travel-store
# Company Link 7493: https://builtinla.com/company/fusefx
# Company Link 7494: https://builtinla.com/company/parentsquare
# Company Link 7495: https://builtinla.com/company/zevia
# Company Link 7496: https://builtinla.com/company/social-cafe-seven
# Company Link 7497: https://builtinla.com/company/pyng-community-messaging
# Company Link 7498: https://builtinla.com/company/pearl-abyss-america-inc
# Company Link 7499: https://builtinla.com/company/visitors-insurance
# Company Link 7500: https://builtinla.com/company/archideators
# Company Link 7501: https://builtinla.com/company/liquid-inc
# Company Link 7502: https://builtinla.com/company/incharge-energy
# Company Link 7503: https://builtinla.com/company/eh-attorneys
# Company Link 7504: https://builtinla.com/company/klickly-inc
# Company Link 7505: https://builtinla.com/company/aglet
# Company Link 7506: https://builtinla.com/company/sketchy
# Company Link 7507: https://builtinla.com/company/rila-inc
# Company Link 7508: https://builtinla.com/company/steno-0
# Company Link 7509: https://builtinla.com/company/tapcheck
# Company Link 7510: https://builtinla.com/company/jordan-belfort
# Company Link 7511: https://builtinla.com/company/citrus-logo-design
# Company Link 7512: https://builtinla.com/company/agedebayaccounts
# Company Link 7513: https://builtinla.com/company/buildlane
# Company Link 7514: https://builtinla.com/company/lulu-and-georgia
# Company Link 7515: https://builtinla.com/company/unis
# Company Link 7516: https://builtinla.com/company/shuup
# Company Link 7517: https://builtinla.com/company/temper
# Company Link 7518: https://builtinla.com/company/nrg-esports
# Company Link 7519: https://builtinla.com/company/changefi
# Company Link 7520: https://builtinla.com/company/liamtra
# Company Link 7521: https://builtinla.com/company/buildlane
# Company Link 7522: https://builtinla.com/company/aetion
# Company Link 7523: https://builtinla.com/company/tk-digitals
# Company Link 7524: https://builtinla.com/company/trackmind-solutions
# Company Link 7525: https://builtinla.com/company/lulu-and-georgia
# Company Link 7526: https://builtinla.com/company/vidiq-1
# Company Link 7527: https://builtinla.com/company/shop-premium-outlets-rue-gilt-groupe
# Company Link 7528: https://builtinla.com/company/website-design-flex
# Company Link 7529: https://builtinla.com/company/ninehertz
# Company Link 7530: https://builtinla.com/company/sm-innovations
# Company Link 7531: https://builtinla.com/company/changefi
# Company Link 7532: https://builtinla.com/company/instrument
# Company Link 7533: https://builtinla.com/company/el-dorado-digital
# Company Link 7534: https://builtinla.com/company/ravyn
# Company Link 7535: https://builtinla.com/company/opte
# Company Link 7536: https://builtinla.com/company/qm-social-music
# Company Link 7537: https://builtinla.com/company/flow-finance
# Company Link 7538: https://builtinla.com/company/mavie-solutions-inc
# Company Link 7539: https://builtinla.com/company/career-opportunities-international
# Company Link 7540: https://builtinla.com/company/pacific-air-industries
# Company Link 7541: https://builtinla.com/company/maykit
# Company Link 7542: https://builtinla.com/company/fullfill-inc
# Company Link 7543: https://builtinla.com/company/eduhelpershub-reviews
# Company Link 7544: https://builtinla.com/company/grab-labs
# Company Link 7545: https://builtinla.com/company/unique-unions-llc
# Company Link 7546: https://builtinla.com/company/website-development-company
# Company Link 7547: https://builtinla.com/company/black-car-rides
# Company Link 7548: https://builtinla.com/company/vitalacy-inc
# Company Link 7549: https://builtinla.com/company/lady-indy
# Company Link 7550: https://builtinla.com/company/chime
# Company Link 7551: https://builtinla.com/company/allvoices
# Company Link 7552: https://builtinla.com/company/intellectual-beam
# Company Link 7553: https://builtinla.com/company/3deo
# Company Link 7554: https://builtinla.com/company/talkshoplive
# Company Link 7555: https://builtinla.com/company/robin
# Company Link 7556: https://builtinla.com/company/website-development-company-1
# Company Link 7557: https://builtinla.com/company/syndigo
# Company Link 7558: https://builtinla.com/company/party-round
# Company Link 7559: https://builtinla.com/company/vista-logos
# Company Link 7560: https://builtinla.com/company/educators-lodge
# Company Link 7561: https://builtinla.com/company/tango
# Company Link 7562: https://builtinla.com/company/appsumo
# Company Link 7563: https://builtinla.com/company/greg
# Company Link 7564: https://builtinla.com/company/renee
# Company Link 7565: https://builtinla.com/company/grab-labs
# Company Link 7566: https://builtinla.com/company/night-school-studio
# Company Link 7567: https://builtinla.com/company/frame-fitness
# Company Link 7568: https://builtinla.com/company/step-tutoring
# Company Link 7569: https://builtinla.com/company/swiss-post-solutions-north-america
# Company Link 7570: https://builtinla.com/company/website-development-company-0
# Company Link 7571: https://builtinla.com/company/myagi
# Company Link 7572: https://builtinla.com/company/kustom-kit-gym-equipment
# Company Link 7573: https://builtinla.com/company/lit-method
# Company Link 7574: https://builtinla.com/company/griot
# Company Link 7575: https://builtinla.com/company/active-theory
# Company Link 7576: https://builtinla.com/company/crazy-safety
# Company Link 7577: https://builtinla.com/company/hd-buttercup
# Company Link 7578: https://builtinla.com/company/3deo
# Company Link 7579: https://builtinla.com/company/itv-studios-america
# Company Link 7580: https://builtinla.com/company/elodie-games
# Company Link 7581: https://builtinla.com/company/de-soi
# Company Link 7582: https://builtinla.com/company/michelson-philanthropies
# Company Link 7583: https://builtinla.com/company/nautical-llc
# Company Link 7584: https://builtinla.com/company/huckleberry-labs
# Company Link 7585: https://builtinla.com/company/mudwtr
# Company Link 7586: https://builtinla.com/company/coast-digital
# Company Link 7587: https://builtinla.com/company/livespace
# Company Link 7588: https://builtinla.com/company/nomostache
# Company Link 7589: https://builtinla.com/company/etta
# Company Link 7590: https://builtinla.com/company/venturecount-llc
# Company Link 7591: https://builtinla.com/company/flawless
# Company Link 7592: https://builtinla.com/company/trueparity
# Company Link 7593: https://builtinla.com/company/aurora-moving-company
# Company Link 7594: https://builtinla.com/company/emrcpr
# Company Link 7595: https://builtinla.com/company/kaiyo
# Company Link 7596: https://builtinla.com/company/barrington-drafting-service-llc
# Company Link 7597: https://builtinla.com/company/ten-thousand-coffees
# Company Link 7598: https://builtinla.com/company/options-md
# Company Link 7599: https://builtinla.com/company/navitas-semiconductor
# Company Link 7600: https://builtinla.com/company/mcdowall-integrative-psychology-healthcare-anger-management-therapy
# Company Link 7601: https://builtinla.com/company/luckmon
# Company Link 7602: https://builtinla.com/company/greatbuildz
# Company Link 7603: https://builtinla.com/company/expert-towing-0
# Company Link 7604: https://builtinla.com/company/daesha-transit-llc
# Company Link 7605: https://builtinla.com/company/sega-america
# Company Link 7606: https://builtinla.com/company/legendary-entertainment
# Company Link 7607: https://builtinla.com/company/bestgenmedrx-0
# Company Link 7608: https://builtinla.com/company/prodoscore
# Company Link 7609: https://builtinla.com/company/live-data-technologies
# Company Link 7610: https://builtinla.com/company/hansens-moving-and-storage-0
# Company Link 7611: https://builtinla.com/company/hed-social
# Company Link 7612: https://builtinla.com/company/rule-cosmeceuticals
# Company Link 7613: https://builtinla.com/company/spartan-radar-0
# Company Link 7614: https://builtinla.com/company/stylette
# Company Link 7615: https://builtinla.com/company/seo-vivek-rana
# Company Link 7616: https://builtinla.com/company/article-submission-directories
# Company Link 7617: https://builtinla.com/company/pagos-solutions
# Company Link 7618: https://builtinla.com/company/meta-hollywood
# Company Link 7619: https://builtinla.com/company/rain-0
# Company Link 7620: https://builtinla.com/company/autio
# Company Link 7621: https://builtinla.com/company/la-hvac-expert
# Company Link 7622: https://builtinla.com/company/primitive-spark
# Company Link 7623: https://builtinla.com/company/meta-hollywood
# Company Link 7624: https://builtinla.com/company/sky-bri
# Company Link 7625: https://builtinla.com/company/wow-how
# Company Link 7626: https://builtinla.com/company/venus-et-fleur
# Company Link 7627: https://builtinla.com/company/angel-city
# Company Link 7628: https://builtinla.com/company/eaton
# Company Link 7629: https://builtinla.com/company/hoverstate
# Company Link 7630: https://builtinla.com/company/joni-and-friends
# Company Link 7631: https://builtinla.com/company/kyro-digital-corp
# Company Link 7632: https://builtinla.com/company/mammoth-distribution
# Company Link 7633: https://builtinla.com/company/nlx
# Company Link 7634: https://builtinla.com/company/place-showroom
# Company Link 7635: https://builtinla.com/company/senior-lifestyle
# Company Link 7636: https://builtinla.com/company/sp6
# Company Link 7637: https://builtinla.com/company/decktopus
# Company Link 7638: https://builtinla.com/company/kamagra-gold-vcarepharmacy
# Company Link 7639: https://builtinla.com/company/we-code-future
# Company Link 7640: https://builtinla.com/company/mend

# %%
import requests
from bs4 import BeautifulSoup
import csv

def scrape_company_links(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    # Scraping company links
    company_links = []
    company_elements = soup.find_all("a", class_="btn btn-lg btn-outline-primary w-100")
    company_links = [company.get("href") for company in company_elements]

    return company_links

def scrape_official_link(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    # Find the anchor tag with the specified class
    company_link_element = soup.find('a', class_='info-item company-website-link')

    # Extract the href attribute (company link)
    company_link = company_link_element['href'] if company_link_element else None

    return company_link

# Base URL
base_url = 'https://www.builtinla.com/companies?page={}'

# Number of pages to scrape (382 in this case)
total_pages = 3

# List to store company links
all_company_links = []

# Iterate over each page and scrape company links
for page_number in range(1, total_pages + 1):
    current_url = base_url.format(page_number)
    company_links = scrape_company_links(current_url)
    all_company_links.extend(company_links)

# List to store company data (names, links, and official links)
all_companies_data = []

# Iterate through the list of company links and scrape official company links
for company_link in all_company_links:
    official_link = scrape_official_link(company_link)
    all_companies_data.append((company_link, official_link))

# Save all company data to CSV file
csv_file_path = 'all_companies_data.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write the header row
    csv_writer.writerow(['Company Link', 'Official Link'])

    # Write the company data to the CSV file
    for company_data in all_companies_data:
        csv_writer.writerow(company_data)

print(f"All company data (links and official links) have been successfully written to {csv_file_path}.")
# Out:
# All company data (links and official links) have been successfully written to all_companies_data.csv.

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Function to scrape company names and links from a given URL
def scrape_company_data(url):
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')

    # Scraping company names
    company_names = []
    company_list = soup.find_all("h2", class_="fw-extrabold fs-xl hover-underline d-inline-block company-title-clamp mb-0")
    company_names = [company.get_text(strip=True) for company in company_list]

    # Scraping company links
    company_links = []
    company_elements = soup.find_all("a", class_="btn btn-lg btn-outline-primary w-100")
    company_links = [company.get("href") for company in company_elements]

    return list(zip(company_names, company_links))

# Base URL
base_url = 'https://www.builtinla.com/companies?page={}'

# Number of pages to scrape (let's scrape the first 10 pages, each page contains around 100 companies)
pages_to_scrape = 10

# List to store company data (names and links)
all_companies_data = []

# Iterate over each page and scrape company data
for page_number in range(1, pages_to_scrape + 1):
    current_url = base_url.format(page_number)
    companies_data = scrape_company_data(current_url)
    all_companies_data.extend(companies_data)

# Save all company data to CSV file
csv_file_path = 'all_companies_data.csv'
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)

    # Write the header row
    csv_writer.writerow(['Company Name', 'Company Link'])

    # Write the company data to the CSV file
    for company in all_companies_data:
        csv_writer.writerow(company)

print(f"The first 1000 companies' names and links have been successfully written to {csv_file_path}.")
# Out:
# The first 1000 companies' names and links have been successfully written to all_companies_data.csv.
